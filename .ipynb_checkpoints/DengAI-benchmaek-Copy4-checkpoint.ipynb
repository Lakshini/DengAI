# %%
from __future__ import print_function
from __future__ import division
# %matplotlib inline
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import preprocessing

from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# just for the sake of this blog post!
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# load the provided data
train_features = pd.read_csv('data-processed/dengue_features_train.csv',
                             index_col=[0,1,2])

train_labels = pd.read_csv('data-processed/dengue_labels_train.csv',
                           index_col=[0,1,2])

# %%
train_features.shape
# Out:
# (1456, 22)

# %%
train_features_shifted1 = train_features.shift(1,axis = 0)
train_features_shifted2 = train_features.shift(2,axis = 0)

# %%
train_features_shifted1 = train_features_shifted1.rename(columns={'week_start_date':'week_start_date_pr1',
 'ndvi_ne':'ndvi_ne_pr1',
 'ndvi_nw':'ndvi_nw_pr1',
 'ndvi_se':'ndvi_se_Pr1',
 'ndvi_sw':'ndvi_sw_pr1',
 'precipitation_amt_mm':'precipitation_amt_mm_pr1',
 'reanalysis_air_temp_k':'reanalysis_air_temp_k_pr1',
 'reanalysis_avg_temp_k':'reanalysis_avg_temp_k_pr1',
 'reanalysis_dew_point_temp_k':'reanalysis_dew_point_temp_k_pr1',
 'reanalysis_max_air_temp_k':'reanalysis_max_air_temp_k_pr1',
 'reanalysis_min_air_temp_k':'reanalysis_min_air_temp_k_pr1',
 'reanalysis_precip_amt_kg_per_m2':'reanalysis_precip_amt_kg_per_m2_pr1',
 'reanalysis_relative_humidity_percent':'reanalysis_relative_humidity_percent_pr1',
 'reanalysis_sat_precip_amt_mm':'reanalysis_sat_precip_amt_mm_pr1',
 'reanalysis_specific_humidity_g_per_kg':'reanalysis_specific_humidity_g_per_kg_pr1',
 'reanalysis_tdtr_k':'reanalysis_tdtr_k_pr1',
 'station_avg_temp_c':'station_avg_temp_c_pr1',
 'station_diur_temp_rng_c':'station_diur_temp_rng_c_pr1',
 'station_max_temp_c':'station_max_temp_c_pr1',
 'station_min_temp_c':'station_min_temp_c_pr1',
 'station_precip_mm':'station_precip_mm_pr1'})

# %%
train_features_shifted1.head()
# Out:
#                      week_start_date_pr1  ndvi_ne_pr1  ndvi_nw_pr1  \
# city year weekofyear
# sj   1990 18                         NaN          NaN          NaN
#           19                  1990-04-30     0.122600     0.103725
#           20                  1990-05-07     0.169900     0.142175
#           21                  1990-05-14     0.032250     0.172967
#           22                  1990-05-21     0.128633     0.245067
#
#                       ndvi_se_Pr1  ndvi_sw_pr1  precipitation_amt_mm_pr1  \
# city year weekofyear
# sj   1990 18                  NaN          NaN                       NaN
#           19             0.198483     0.177617                     12.42
#           20             0.162357     0.155486                     22.82
#           21             0.157200     0.170843                     34.54
#           22             0.227557     0.235886                     15.36
#
#                       reanalysis_air_temp_k_pr1  reanalysis_avg_temp_k_pr1  \
# city year weekofyear
# sj   1990 18                                NaN                        NaN
#           19                         297.572857                 297.742857
#           20                         298.211429                 298.442857
#           21                         298.781429                 298.878571
#           22                         298.987143                 299.228571
#
#                       reanalysis_dew_point_temp_k_pr1  \
# city year weekofyear
# sj   1990 18                                      NaN
#           19                               292.414286
#           20                               293.951429
#           21                               295.434286
#           22                               295.310000
#
#                       reanalysis_max_air_temp_k_pr1  ...  \
# city year weekofyear                                 ...
# sj   1990 18                                    NaN  ...
#           19                                  299.8  ...
#           20                                  300.9  ...
#           21                                  300.5  ...
#           22                                  301.4  ...
#
#                       reanalysis_relative_humidity_percent_pr1  \
# city year weekofyear
# sj   1990 18                                               NaN
#           19                                         73.365714
#           20                                         77.368571
#           21                                         82.052857
#           22                                         80.337143
#
#                       reanalysis_sat_precip_amt_mm_pr1  \
# city year weekofyear
# sj   1990 18                                       NaN
#           19                                     12.42
#           20                                     22.82
#           21                                     34.54
#           22                                     15.36
#
#                       reanalysis_specific_humidity_g_per_kg_pr1  \
# city year weekofyear
# sj   1990 18                                                NaN
#           19                                          14.012857
#           20                                          15.372857
#           21                                          16.848571
#           22                                          16.672857
#
#                       reanalysis_tdtr_k_pr1  station_avg_temp_c_pr1  \
# city year weekofyear
# sj   1990 18                            NaN                     NaN
#           19                       2.628571               25.442857
#           20                       2.371429               26.714286
#           21                       2.300000               26.714286
#           22                       2.428571               27.471429
#
#                       station_diur_temp_rng_c_pr1  station_max_temp_c_pr1  \
# city year weekofyear
# sj   1990 18                                  NaN                     NaN
#           19                             6.900000                    29.4
#           20                             6.371429                    31.7
#           21                             6.485714                    32.2
#           22                             6.771429                    33.3
#
#                       station_min_temp_c_pr1  station_precip_mm_pr1  months
# city year weekofyear
# sj   1990 18                             NaN                    NaN     NaN
#           19                            20.0                   16.0     4.0
#           20                            22.2                    8.6     5.0
#           21                            22.8                   41.4     5.0
#           22                            23.3                    4.0     5.0
#
# [5 rows x 22 columns]

# %%
train_features_shifted2 = train_features_shifted2.rename(columns={'week_start_date':'week_start_date_pr2',
 'ndvi_ne':'ndvi_ne_pr2',
 'ndvi_nw':'ndvi_nw_pr2',
 'ndvi_se':'ndvi_se_Pr2',
 'ndvi_sw':'ndvi_sw_pr2',
 'precipitation_amt_mm':'precipitation_amt_mm_pr2',
 'reanalysis_air_temp_k':'reanalysis_air_temp_k_pr2',
 'reanalysis_avg_temp_k':'reanalysis_avg_temp_k_pr2',
 'reanalysis_dew_point_temp_k':'reanalysis_dew_point_temp_k_pr2',
 'reanalysis_max_air_temp_k':'reanalysis_max_air_temp_k_pr2',
 'reanalysis_min_air_temp_k':'reanalysis_min_air_temp_k_pr2',
 'reanalysis_precip_amt_kg_per_m2':'reanalysis_precip_amt_kg_per_m2_pr2',
 'reanalysis_relative_humidity_percent':'reanalysis_relative_humidity_percent_pr2',
 'reanalysis_sat_precip_amt_mm':'reanalysis_sat_precip_amt_mm_pr2',
 'reanalysis_specific_humidity_g_per_kg':'reanalysis_specific_humidity_g_per_kg_pr2',
 'reanalysis_tdtr_k':'reanalysis_tdtr_k_pr2',
 'station_avg_temp_c':'station_avg_temp_c_pr2',
 'station_diur_temp_rng_c':'station_diur_temp_rng_c_pr2',
 'station_max_temp_c':'station_max_temp_c_pr2',
 'station_min_temp_c':'station_min_temp_c_pr2',
 'station_precip_mm':'station_precip_mm_pr2'})

# %%
train_features_shifted2.head()
# Out:
#                      week_start_date_pr2  ndvi_ne_pr2  ndvi_nw_pr2  \
# city year weekofyear
# sj   1990 18                         NaN          NaN          NaN
#           19                         NaN          NaN          NaN
#           20                  1990-04-30      0.12260     0.103725
#           21                  1990-05-07      0.16990     0.142175
#           22                  1990-05-14      0.03225     0.172967
#
#                       ndvi_se_Pr2  ndvi_sw_pr2  precipitation_amt_mm_pr2  \
# city year weekofyear
# sj   1990 18                  NaN          NaN                       NaN
#           19                  NaN          NaN                       NaN
#           20             0.198483     0.177617                     12.42
#           21             0.162357     0.155486                     22.82
#           22             0.157200     0.170843                     34.54
#
#                       reanalysis_air_temp_k_pr2  reanalysis_avg_temp_k_pr2  \
# city year weekofyear
# sj   1990 18                                NaN                        NaN
#           19                                NaN                        NaN
#           20                         297.572857                 297.742857
#           21                         298.211429                 298.442857
#           22                         298.781429                 298.878571
#
#                       reanalysis_dew_point_temp_k_pr2  \
# city year weekofyear
# sj   1990 18                                      NaN
#           19                                      NaN
#           20                               292.414286
#           21                               293.951429
#           22                               295.434286
#
#                       reanalysis_max_air_temp_k_pr2  ...  \
# city year weekofyear                                 ...
# sj   1990 18                                    NaN  ...
#           19                                    NaN  ...
#           20                                  299.8  ...
#           21                                  300.9  ...
#           22                                  300.5  ...
#
#                       reanalysis_relative_humidity_percent_pr2  \
# city year weekofyear
# sj   1990 18                                               NaN
#           19                                               NaN
#           20                                         73.365714
#           21                                         77.368571
#           22                                         82.052857
#
#                       reanalysis_sat_precip_amt_mm_pr2  \
# city year weekofyear
# sj   1990 18                                       NaN
#           19                                       NaN
#           20                                     12.42
#           21                                     22.82
#           22                                     34.54
#
#                       reanalysis_specific_humidity_g_per_kg_pr2  \
# city year weekofyear
# sj   1990 18                                                NaN
#           19                                                NaN
#           20                                          14.012857
#           21                                          15.372857
#           22                                          16.848571
#
#                       reanalysis_tdtr_k_pr2  station_avg_temp_c_pr2  \
# city year weekofyear
# sj   1990 18                            NaN                     NaN
#           19                            NaN                     NaN
#           20                       2.628571               25.442857
#           21                       2.371429               26.714286
#           22                       2.300000               26.714286
#
#                       station_diur_temp_rng_c_pr2  station_max_temp_c_pr2  \
# city year weekofyear
# sj   1990 18                                  NaN                     NaN
#           19                                  NaN                     NaN
#           20                             6.900000                    29.4
#           21                             6.371429                    31.7
#           22                             6.485714                    32.2
#
#                       station_min_temp_c_pr2  station_precip_mm_pr2  months
# city year weekofyear
# sj   1990 18                             NaN                    NaN     NaN
#           19                             NaN                    NaN     NaN
#           20                            20.0                   16.0     4.0
#           21                            22.2                    8.6     5.0
#           22                            22.8                   41.4     5.0
#
# [5 rows x 22 columns]

# %%
df_cd = pd.merge(train_features_shifted1, train_features_shifted2, how='inner',on =['city','year','weekofyear' ])

# %%
shifted_dataset_full = pd.merge(df_cd, train_features, how='inner',on =['city','year','weekofyear' ])

# %%
shifted_dataset_full.head()
# Out:
#                      week_start_date_pr1  ndvi_ne_pr1  ndvi_nw_pr1  \
# city year weekofyear
# sj   1990 18                         NaN          NaN          NaN
#           19                  1990-04-30     0.122600     0.103725
#           20                  1990-05-07     0.169900     0.142175
#           21                  1990-05-14     0.032250     0.172967
#           22                  1990-05-21     0.128633     0.245067
#
#                       ndvi_se_Pr1  ndvi_sw_pr1  precipitation_amt_mm_pr1  \
# city year weekofyear
# sj   1990 18                  NaN          NaN                       NaN
#           19             0.198483     0.177617                     12.42
#           20             0.162357     0.155486                     22.82
#           21             0.157200     0.170843                     34.54
#           22             0.227557     0.235886                     15.36
#
#                       reanalysis_air_temp_k_pr1  reanalysis_avg_temp_k_pr1  \
# city year weekofyear
# sj   1990 18                                NaN                        NaN
#           19                         297.572857                 297.742857
#           20                         298.211429                 298.442857
#           21                         298.781429                 298.878571
#           22                         298.987143                 299.228571
#
#                       reanalysis_dew_point_temp_k_pr1  \
# city year weekofyear
# sj   1990 18                                      NaN
#           19                               292.414286
#           20                               293.951429
#           21                               295.434286
#           22                               295.310000
#
#                       reanalysis_max_air_temp_k_pr1  ...  \
# city year weekofyear                                 ...
# sj   1990 18                                    NaN  ...
#           19                                  299.8  ...
#           20                                  300.9  ...
#           21                                  300.5  ...
#           22                                  301.4  ...
#
#                       reanalysis_relative_humidity_percent  \
# city year weekofyear
# sj   1990 18                                     73.365714
#           19                                     77.368571
#           20                                     82.052857
#           21                                     80.337143
#           22                                     80.460000
#
#                       reanalysis_sat_precip_amt_mm  \
# city year weekofyear
# sj   1990 18                                 12.42
#           19                                 22.82
#           20                                 34.54
#           21                                 15.36
#           22                                  7.52
#
#                       reanalysis_specific_humidity_g_per_kg  \
# city year weekofyear
# sj   1990 18                                      14.012857
#           19                                      15.372857
#           20                                      16.848571
#           21                                      16.672857
#           22                                      17.210000
#
#                       reanalysis_tdtr_k  station_avg_temp_c  \
# city year weekofyear
# sj   1990 18                   2.628571           25.442857
#           19                   2.371429           26.714286
#           20                   2.300000           26.714286
#           21                   2.428571           27.471429
#           22                   3.014286           28.942857
#
#                       station_diur_temp_rng_c  station_max_temp_c  \
# city year weekofyear
# sj   1990 18                         6.900000                29.4
#           19                         6.371429                31.7
#           20                         6.485714                32.2
#           21                         6.771429                33.3
#           22                         9.371429                35.0
#
#                       station_min_temp_c  station_precip_mm  months
# city year weekofyear
# sj   1990 18                        20.0               16.0       4
#           19                        22.2                8.6       5
#           20                        22.8               41.4       5
#           21                        23.3                4.0       5
#           22                        23.9                5.8       5
#
# [5 rows x 66 columns]

# %%
# Seperate data for San Juan
sj_train_features = shifted_dataset_full.loc['sj']
sj_train_labels = train_labels.loc['sj']

# Separate data for Iquitos
iq_train_features = shifted_dataset_full.loc['iq']
iq_train_labels = train_labels.loc['iq']

# %%
sj_train_features.head()
# Out:
#                 week_start_date_pr1  ndvi_ne_pr1  ndvi_nw_pr1  ndvi_se_Pr1  \
# year weekofyear
# 1990 18                         NaN          NaN          NaN          NaN
#      19                  1990-04-30     0.122600     0.103725     0.198483
#      20                  1990-05-07     0.169900     0.142175     0.162357
#      21                  1990-05-14     0.032250     0.172967     0.157200
#      22                  1990-05-21     0.128633     0.245067     0.227557
#
#                  ndvi_sw_pr1  precipitation_amt_mm_pr1  \
# year weekofyear
# 1990 18                  NaN                       NaN
#      19             0.177617                     12.42
#      20             0.155486                     22.82
#      21             0.170843                     34.54
#      22             0.235886                     15.36
#
#                  reanalysis_air_temp_k_pr1  reanalysis_avg_temp_k_pr1  \
# year weekofyear
# 1990 18                                NaN                        NaN
#      19                         297.572857                 297.742857
#      20                         298.211429                 298.442857
#      21                         298.781429                 298.878571
#      22                         298.987143                 299.228571
#
#                  reanalysis_dew_point_temp_k_pr1  \
# year weekofyear
# 1990 18                                      NaN
#      19                               292.414286
#      20                               293.951429
#      21                               295.434286
#      22                               295.310000
#
#                  reanalysis_max_air_temp_k_pr1  ...  \
# year weekofyear                                 ...
# 1990 18                                    NaN  ...
#      19                                  299.8  ...
#      20                                  300.9  ...
#      21                                  300.5  ...
#      22                                  301.4  ...
#
#                  reanalysis_relative_humidity_percent  \
# year weekofyear
# 1990 18                                     73.365714
#      19                                     77.368571
#      20                                     82.052857
#      21                                     80.337143
#      22                                     80.460000
#
#                  reanalysis_sat_precip_amt_mm  \
# year weekofyear
# 1990 18                                 12.42
#      19                                 22.82
#      20                                 34.54
#      21                                 15.36
#      22                                  7.52
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# year weekofyear
# 1990 18                                      14.012857           2.628571
#      19                                      15.372857           2.371429
#      20                                      16.848571           2.300000
#      21                                      16.672857           2.428571
#      22                                      17.210000           3.014286
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# year weekofyear
# 1990 18                   25.442857                 6.900000
#      19                   26.714286                 6.371429
#      20                   26.714286                 6.485714
#      21                   27.471429                 6.771429
#      22                   28.942857                 9.371429
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm  \
# year weekofyear
# 1990 18                        29.4                20.0               16.0
#      19                        31.7                22.2                8.6
#      20                        32.2                22.8               41.4
#      21                        33.3                23.3                4.0
#      22                        35.0                23.9                5.8
#
#                  months
# year weekofyear
# 1990 18               4
#      19               5
#      20               5
#      21               5
#      22               5
#
# [5 rows x 66 columns]

# %%
# Remove `week_start_date` string.
sj_train_features.drop('week_start_date', axis=1, inplace=True)
iq_train_features.drop('week_start_date', axis=1, inplace=True)

sj_train_features.drop('week_start_date_pr1', axis=1, inplace=True)
iq_train_features.drop('week_start_date_pr1', axis=1, inplace=True)

sj_train_features.drop('week_start_date_pr2', axis=1, inplace=True)
iq_train_features.drop('week_start_date_pr2', axis=1, inplace=True)

# %%
sj_train_features.head()
# Out:
#                  ndvi_ne_pr1  ndvi_nw_pr1  ndvi_se_Pr1  ndvi_sw_pr1  \
# year weekofyear
# 1990 18                  NaN          NaN          NaN          NaN
#      19             0.122600     0.103725     0.198483     0.177617
#      20             0.169900     0.142175     0.162357     0.155486
#      21             0.032250     0.172967     0.157200     0.170843
#      22             0.128633     0.245067     0.227557     0.235886
#
#                  precipitation_amt_mm_pr1  reanalysis_air_temp_k_pr1  \
# year weekofyear
# 1990 18                               NaN                        NaN
#      19                             12.42                 297.572857
#      20                             22.82                 298.211429
#      21                             34.54                 298.781429
#      22                             15.36                 298.987143
#
#                  reanalysis_avg_temp_k_pr1  reanalysis_dew_point_temp_k_pr1  \
# year weekofyear
# 1990 18                                NaN                              NaN
#      19                         297.742857                       292.414286
#      20                         298.442857                       293.951429
#      21                         298.878571                       295.434286
#      22                         299.228571                       295.310000
#
#                  reanalysis_max_air_temp_k_pr1  reanalysis_min_air_temp_k_pr1  \
# year weekofyear
# 1990 18                                    NaN                            NaN
#      19                                  299.8                          295.9
#      20                                  300.9                          296.4
#      21                                  300.5                          297.3
#      22                                  301.4                          297.0
#
#                  ...  reanalysis_relative_humidity_percent  \
# year weekofyear  ...
# 1990 18          ...                             73.365714
#      19          ...                             77.368571
#      20          ...                             82.052857
#      21          ...                             80.337143
#      22          ...                             80.460000
#
#                  reanalysis_sat_precip_amt_mm  \
# year weekofyear
# 1990 18                                 12.42
#      19                                 22.82
#      20                                 34.54
#      21                                 15.36
#      22                                  7.52
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# year weekofyear
# 1990 18                                      14.012857           2.628571
#      19                                      15.372857           2.371429
#      20                                      16.848571           2.300000
#      21                                      16.672857           2.428571
#      22                                      17.210000           3.014286
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# year weekofyear
# 1990 18                   25.442857                 6.900000
#      19                   26.714286                 6.371429
#      20                   26.714286                 6.485714
#      21                   27.471429                 6.771429
#      22                   28.942857                 9.371429
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm  \
# year weekofyear
# 1990 18                        29.4                20.0               16.0
#      19                        31.7                22.2                8.6
#      20                        32.2                22.8               41.4
#      21                        33.3                23.3                4.0
#      22                        35.0                23.9                5.8
#
#                  months
# year weekofyear
# 1990 18               4
#      19               5
#      20               5
#      21               5
#      22               5
#
# [5 rows x 63 columns]

# %%
sj_train_features = (sj_train_features-sj_train_features.min())/(sj_train_features.max()-sj_train_features.min())
iq_train_features = (iq_train_features-iq_train_features.min())/(iq_train_features.max()-iq_train_features.min())

# %%
sj_train_features.head()
# Out:
#                  ndvi_ne_pr1  ndvi_nw_pr1  ndvi_se_Pr1  ndvi_sw_pr1  \
# year weekofyear
# 1990 18                  NaN          NaN          NaN          NaN
#      19             0.587840     0.626763     0.523701     0.541889
#      20             0.640416     0.669811     0.435300     0.492142
#      21             0.487412     0.704284     0.422680     0.526662
#      22             0.594546     0.785005     0.594845     0.672866
#
#                  precipitation_amt_mm_pr1  reanalysis_air_temp_k_pr1  \
# year weekofyear
# 1990 18                               NaN                        NaN
#      19                          0.031797                   0.326368
#      20                          0.058423                   0.419333
#      21                          0.088428                   0.502315
#      22                          0.039324                   0.532263
#
#                  reanalysis_avg_temp_k_pr1  reanalysis_dew_point_temp_k_pr1  \
# year weekofyear
# 1990 18                                NaN                              NaN
#      19                           0.272298                         0.339933
#      20                           0.387508                         0.528474
#      21                           0.459220                         0.710356
#      22                           0.516825                         0.695111
#
#                  reanalysis_max_air_temp_k_pr1  reanalysis_min_air_temp_k_pr1  \
# year weekofyear
# 1990 18                                    NaN                            NaN
#      19                               0.307692                       0.452055
#      20                               0.476923                       0.520548
#      21                               0.415385                       0.643836
#      22                               0.553846                       0.602740
#
#                  ...  reanalysis_relative_humidity_percent  \
# year weekofyear  ...
# 1990 18          ...                              0.318138
#      19          ...                              0.510214
#      20          ...                              0.734988
#      21          ...                              0.652660
#      22          ...                              0.658555
#
#                  reanalysis_sat_precip_amt_mm  \
# year weekofyear
# 1990 18                              0.031797
#      19                              0.058423
#      20                              0.088428
#      21                              0.039324
#      22                              0.019252
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# year weekofyear
# 1990 18                                       0.297392           0.412955
#      19                                       0.473460           0.329436
#      20                                       0.664509           0.306237
#      21                                       0.641761           0.347996
#      22                                       0.711300           0.538234
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# year weekofyear
# 1990 18                    0.359684                 0.440318
#      19                    0.535573                 0.342175
#      20                    0.535573                 0.363395
#      21                    0.640316                 0.416446
#      22                    0.843874                 0.899204
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm  \
# year weekofyear
# 1990 18                    0.303371            0.282051           0.052305
#      19                    0.561798            0.564103           0.028114
#      20                    0.617978            0.641026           0.135338
#      21                    0.741573            0.705128           0.013076
#      22                    0.932584            0.782051           0.018960
#
#                    months
# year weekofyear
# 1990 18          0.272727
#      19          0.363636
#      20          0.363636
#      21          0.363636
#      22          0.363636
#
# [5 rows x 63 columns]

# %%
# Seperate data for San Juan
#sj_train_features = shifted_dataset_full.loc['sj']
#sj_train_labels = train_labels.loc['sj']

# Separate data for Iquitos
#iq_train_features = shifted_dataset_full.loc['iq']
#iq_train_labels = train_labels.loc['iq']

# %%
# Remove `week_start_date` string.
#sj_train_features.drop('week_start_date', axis=1, inplace=True)
#iq_train_features.drop('week_start_date', axis=1, inplace=True)
#sj_train_features.drop('week_start_date_pr1', axis=1, inplace=True)
#iq_train_features.drop('week_start_date_pr1', axis=1, inplace=True)
#sj_train_features.drop('week_start_date_pr2', axis=1, inplace=True)
#iq_train_features.drop('week_start_date_pr2', axis=1, inplace=True)

# %%
sj_train_features.fillna(sj_train_features.mean(), inplace=True)
iq_train_features.fillna(iq_train_features.mean(), inplace=True)

# %%
sj_train_features['total_cases'] = sj_train_labels.total_cases
iq_train_features['total_cases'] = iq_train_labels.total_cases

# %%
# compute the correlations
sj_correlations = sj_train_features.corr()
iq_correlations = iq_train_features.corr()

# %%
# San Juan
(sj_correlations
     .total_cases
     .drop('total_cases') # don't compare with myself
     .sort_values(ascending=False)
     .plot
     .barh())

# %%
sj_train_features[sj_train_features.columns[1:]].corr()['total_cases'][:]
# Out:
# ndvi_nw_pr1                                 -0.016703
# ndvi_se_Pr1                                 -0.160916
# ndvi_sw_pr1                                 -0.123983
# precipitation_amt_mm_pr1                     0.074424
# reanalysis_air_temp_k_pr1                    0.193229
# reanalysis_avg_temp_k_pr1                    0.189024
# reanalysis_dew_point_temp_k_pr1              0.211728
# reanalysis_max_air_temp_k_pr1                0.210568
# reanalysis_min_air_temp_k_pr1                0.205250
# reanalysis_precip_amt_kg_per_m2_pr1          0.116112
# reanalysis_relative_humidity_percent_pr1     0.143561
# reanalysis_sat_precip_amt_mm_pr1             0.074424
# reanalysis_specific_humidity_g_per_kg_pr1    0.217971
# reanalysis_tdtr_k_pr1                       -0.066330
# station_avg_temp_c_pr1                       0.214814
# station_diur_temp_rng_c_pr1                  0.018845
# station_max_temp_c_pr1                       0.198735
# station_min_temp_c_pr1                       0.202662
# station_precip_mm_pr1                        0.059037
# months_x                                     0.285099
# ndvi_ne_pr2                                 -0.018104
# ndvi_nw_pr2                                 -0.015305
# ndvi_se_Pr2                                 -0.162330
# ndvi_sw_pr2                                 -0.126006
# precipitation_amt_mm_pr2                     0.081543
# reanalysis_air_temp_k_pr2                    0.214428
# reanalysis_avg_temp_k_pr2                    0.209669
# reanalysis_dew_point_temp_k_pr2              0.233653
# reanalysis_max_air_temp_k_pr2                0.226440
# reanalysis_min_air_temp_k_pr2                0.228015
#                                                ...
# reanalysis_specific_humidity_g_per_kg_pr2    0.239287
# reanalysis_tdtr_k_pr2                       -0.080366
# station_avg_temp_c_pr2                       0.242391
# station_diur_temp_rng_c_pr2                  0.012404
# station_max_temp_c_pr2                       0.218215
# station_min_temp_c_pr2                       0.232535
# station_precip_mm_pr2                        0.057802
# months_y                                     0.282823
# ndvi_ne                                     -0.017385
# ndvi_nw                                     -0.021201
# ndvi_se                                     -0.162791
# ndvi_sw                                     -0.133833
# precipitation_amt_mm                         0.058512
# reanalysis_air_temp_k                        0.173019
# reanalysis_avg_temp_k                        0.168623
# reanalysis_dew_point_temp_k                  0.193087
# reanalysis_max_air_temp_k                    0.192285
# reanalysis_min_air_temp_k                    0.182745
# reanalysis_precip_amt_kg_per_m2              0.106074
# reanalysis_relative_humidity_percent         0.137233
# reanalysis_sat_precip_amt_mm                 0.058512
# reanalysis_specific_humidity_g_per_kg        0.199195
# reanalysis_tdtr_k                           -0.062049
# station_avg_temp_c                           0.190920
# station_diur_temp_rng_c                      0.034854
# station_max_temp_c                           0.186955
# station_min_temp_c                           0.170518
# station_precip_mm                            0.050824
# months                                       0.285754
# total_cases                                  1.000000
# Name: total_cases, Length: 63, dtype: float64

# %%
iq_train_features[iq_train_features.columns[1:]].corr()['total_cases'][:]
# Out:
# ndvi_nw_pr1                                 -0.040480
# ndvi_se_Pr1                                 -0.080520
# ndvi_sw_pr1                                 -0.016411
# precipitation_amt_mm_pr1                     0.056299
# reanalysis_air_temp_k_pr1                    0.094787
# reanalysis_avg_temp_k_pr1                    0.077927
# reanalysis_dew_point_temp_k_pr1              0.206308
# reanalysis_max_air_temp_k_pr1               -0.032513
# reanalysis_min_air_temp_k_pr1                0.185890
# reanalysis_precip_amt_kg_per_m2_pr1          0.082820
# reanalysis_relative_humidity_percent_pr1     0.116748
# reanalysis_sat_precip_amt_mm_pr1             0.056299
# reanalysis_specific_humidity_g_per_kg_pr1    0.214118
# reanalysis_tdtr_k_pr1                       -0.102963
# station_avg_temp_c_pr1                       0.120752
# station_diur_temp_rng_c_pr1                 -0.014370
# station_max_temp_c_pr1                       0.078889
# station_min_temp_c_pr1                       0.195705
# station_precip_mm_pr1                        0.045774
# months_x                                    -0.016970
# ndvi_ne_pr2                                 -0.018644
# ndvi_nw_pr2                                 -0.034178
# ndvi_se_Pr2                                 -0.067191
# ndvi_sw_pr2                                 -0.014040
# precipitation_amt_mm_pr2                     0.092631
# reanalysis_air_temp_k_pr2                    0.098669
# reanalysis_avg_temp_k_pr2                    0.089106
# reanalysis_dew_point_temp_k_pr2              0.204453
# reanalysis_max_air_temp_k_pr2               -0.021739
# reanalysis_min_air_temp_k_pr2                0.198692
#                                                ...
# reanalysis_specific_humidity_g_per_kg_pr2    0.212522
# reanalysis_tdtr_k_pr2                       -0.095626
# station_avg_temp_c_pr2                       0.127338
# station_diur_temp_rng_c_pr2                 -0.034580
# station_max_temp_c_pr2                       0.094314
# station_min_temp_c_pr2                       0.191900
# station_precip_mm_pr2                        0.071148
# months_y                                     0.022918
# ndvi_ne                                      0.021028
# ndvi_nw                                     -0.007836
# ndvi_se                                     -0.039923
# ndvi_sw                                      0.033542
# precipitation_amt_mm                         0.094212
# reanalysis_air_temp_k                        0.101513
# reanalysis_avg_temp_k                        0.084748
# reanalysis_dew_point_temp_k                  0.228351
# reanalysis_max_air_temp_k                   -0.047214
# reanalysis_min_air_temp_k                    0.210579
# reanalysis_precip_amt_kg_per_m2              0.103957
# reanalysis_relative_humidity_percent         0.134090
# reanalysis_sat_precip_amt_mm                 0.094212
# reanalysis_specific_humidity_g_per_kg        0.235592
# reanalysis_tdtr_k                           -0.126461
# station_avg_temp_c                           0.061715
# station_diur_temp_rng_c                     -0.046968
# station_max_temp_c                           0.055055
# station_min_temp_c                           0.171874
# station_precip_mm                            0.040963
# months                                      -0.009262
# total_cases                                  1.000000
# Name: total_cases, Length: 63, dtype: float64

# %%
def preprocess_data_iq(data_path, labels_path=None):
    # load data and set index to city, year, weekofyear
    df = data_path
    
    # select features we want
    features = ['reanalysis_dew_point_temp_k',
                'reanalysis_min_air_temp_k',
                'reanalysis_specific_humidity_g_per_kg',
                'station_min_temp_c',
                
                'reanalysis_dew_point_temp_k_pr1',
                'reanalysis_min_air_temp_k_pr1',
                'reanalysis_specific_humidity_g_per_kg_pr1',
                'station_min_temp_c_pr1',
        
                'reanalysis_dew_point_temp_k_pr2',
                'reanalysis_min_air_temp_k_pr2',
                'reanalysis_specific_humidity_g_per_kg_pr2',
                'station_min_temp_c_pr2'
                
             ]
    df = df[features]
    
    # fill missing values
    df.fillna(df.mean(), inplace=True)

    # add labels to dataframe
    if labels_path:
        labels = pd.read_csv(labels_path, index_col=[0, 1, 2])
        df = df.join(labels)
    
    # separate saoin juan and iquitos
    iq = df.loc['iq']
   # iq = df.loc['iq']
    
    return iq

# %%
def preprocess_data_sj(data_path, labels_path=None):
    # load data and set index to city, year, weekofyear
    df = data_path
    
    # select features we want
    features = ['reanalysis_min_air_temp_k',
                'reanalysis_dew_point_temp_k',
                'reanalysis_max_air_temp_k',
                'reanalysis_min_air_temp_k',
                'reanalysis_specific_humidity_g_per_kg',
                'station_avg_temp_c',
                'station_min_temp_c',
                
                'reanalysis_min_air_temp_k_pr1',
                'reanalysis_dew_point_temp_k_pr1',
                'reanalysis_max_air_temp_k_pr1',
                'reanalysis_min_air_temp_k_pr1',
                'reanalysis_specific_humidity_g_per_kg_pr1',
                'station_avg_temp_c_pr1',
                'station_min_temp_c_pr1',
                
                'reanalysis_min_air_temp_k_pr2',
                'reanalysis_dew_point_temp_k_pr2',
                'reanalysis_max_air_temp_k_pr2',
                'reanalysis_min_air_temp_k_pr2',
                'reanalysis_specific_humidity_g_per_kg_pr2',
                'station_avg_temp_c_pr2',
                'station_min_temp_c_pr2'
             ]
    df = df[features]
    
    # fill missing values
    df.fillna(df.mean(), inplace=True)

    # add labels to dataframe
    if labels_path:
        labels = pd.read_csv(labels_path, index_col=[0, 1, 2])
        df = df.join(labels)
    
    # separate saoin juan and iquitos
    sj = df.loc['sj']
   # iq = df.loc['iq']
    
    return sj

# %%
sj_train = preprocess_data_sj(shifted_dataset_full,
                                    labels_path="data-processed/dengue_labels_train.csv")
iq_train = preprocess_data_iq(shifted_dataset_full,
                                    labels_path="data-processed/dengue_labels_train.csv")

# %%
sj_train_subtrain = sj_train.head(800)
sj_train_subtest = sj_train.tail(sj_train.shape[0] - 800)

iq_train_subtrain = iq_train.head(400)
iq_train_subtest = iq_train.tail(iq_train.shape[0] - 400)

# %%
sj_train.shape
# Out:
# (936, 22)

# %%
iq_train.shape
# Out:
# (520, 13)

# %%
from statsmodels.tools import eval_measures
import statsmodels.formula.api as smf

def get_best_model_sj(train, test):
    # Step 1: specify the form of the model
    model_formula = "total_cases ~ 1 + " \
    "reanalysis_min_air_temp_k + " \
                "reanalysis_dew_point_temp_k + " \
                "reanalysis_max_air_temp_k + " \
                "reanalysis_min_air_temp_k + " \
                "reanalysis_specific_humidity_g_per_kg + " \
                "station_avg_temp_c + " \
                "station_min_temp_c + " \
                "reanalysis_min_air_temp_k_pr1 + " \
                "reanalysis_dew_point_temp_k_pr1 + " \
                "reanalysis_max_air_temp_k_pr1 + " \
                "reanalysis_min_air_temp_k_pr1 + " \
                "reanalysis_specific_humidity_g_per_kg_pr1 + " \
                "station_avg_temp_c_pr1 + " \
                "station_min_temp_c_pr1 + " \
                "reanalysis_min_air_temp_k_pr2 + " \
                "reanalysis_dew_point_temp_k_pr2 + " \
                "reanalysis_max_air_temp_k_pr2 + " \
                "reanalysis_min_air_temp_k_pr2 + " \
                "reanalysis_specific_humidity_g_per_kg_pr2 + " \
                "station_avg_temp_c_pr2 + " \
                "station_min_temp_c_pr2"
    
    grid = 10 ** np.arange(-8, -3, dtype=np.float64)
                    
    best_alpha = []
    best_score = 1000
        
    # Step 2: Find the best hyper parameter, alpha
    for alpha in grid:
        model = smf.glm(formula=model_formula,
                        data=train,
                        family=sm.families.NegativeBinomial(alpha=alpha))

        results = model.fit()
        predictions = results.predict(test).astype(int)
        score = eval_measures.meanabs(predictions, test.total_cases)

        if score < best_score:
            best_alpha = alpha
            best_score = score

    print('best alpha = ', best_alpha)
    print('best score = ', best_score)
            
    # Step 3: refit on entire dataset
    full_dataset = pd.concat([train, test])
    model = smf.glm(formula=model_formula,
                    data=full_dataset,
                    family=sm.families.NegativeBinomial(alpha=best_alpha))

    fitted_model = model.fit()
    return fitted_model
    
sj_best_model = get_best_model_sj(sj_train_subtrain, sj_train_subtest)
#iq_best_model = get_best_model_sj(iq_train_subtrain, iq_train_subtest)

figs, axes = plt.subplots(nrows=2, ncols=1)

# plot sj
sj_train['fitted'] = sj_best_model.fittedvalues
sj_train.fitted.plot(ax=axes[0], label="Predictions")
sj_train.total_cases.plot(ax=axes[0], label="Actual")

# plot iq
#iq_train['fitted'] = iq_best_model.fittedvalues
#iq_train.fitted.plot(ax=axes[1], label="Predictions")
#iq_train.total_cases.plot(ax=axes[1], label="Actual")

plt.suptitle("Dengue Predicted Cases vs. Actual Cases")
plt.legend()
# Out:
# No handles with labels found to put in legend.
# best alpha =  1e-08
# best score =  23.191176470588236

# %%
def get_best_model_iq(train, test):
    # Step 1: specify the form of the model
    model_formula = "total_cases ~ 1 + " \
    "reanalysis_dew_point_temp_k + " \
                "reanalysis_min_air_temp_k + " \
                "reanalysis_specific_humidity_g_per_kg + " \
                "station_min_temp_c + " \
                "reanalysis_dew_point_temp_k_pr1 + " \
                "reanalysis_min_air_temp_k_pr1 + " \
                "reanalysis_specific_humidity_g_per_kg_pr1 + " \
                "station_min_temp_c_pr1 + " \
                "reanalysis_dew_point_temp_k_pr2 + " \
                "reanalysis_min_air_temp_k_pr2 + " \
                "reanalysis_specific_humidity_g_per_kg_pr2 + " \
                "station_min_temp_c_pr2"
    
    grid = 10 ** np.arange(-8, -3, dtype=np.float64)
                    
    best_alpha = []
    best_score = 1000
        
    # Step 2: Find the best hyper parameter, alpha
    for alpha in grid:
        model = smf.glm(formula=model_formula,
                        data=train,
                        family=sm.families.NegativeBinomial(alpha=alpha))

        results = model.fit()
        predictions = results.predict(test).astype(int)
        score = eval_measures.meanabs(predictions, test.total_cases)

        if score < best_score:
            best_alpha = alpha
            best_score = score

    print('best alpha = ', best_alpha)
    print('best score = ', best_score)
            
    # Step 3: refit on entire dataset
    full_dataset = pd.concat([train, test])
    model = smf.glm(formula=model_formula,
                    data=full_dataset,
                    family=sm.families.NegativeBinomial(alpha=best_alpha))

    fitted_model = model.fit()
    return fitted_model
    
#sj_best_model = get_best_model_iq(sj_train_subtrain, sj_train_subtest)
iq_best_model = get_best_model_iq(iq_train_subtrain, iq_train_subtest)

figs, axes = plt.subplots(nrows=2, ncols=1)

# plot sj
#sj_train['fitted'] = sj_best_model.fittedvalues
#sj_train.fitted.plot(ax=axes[0], label="Predictions")
#sj_train.total_cases.plot(ax=axes[0], label="Actual")

# plot iq
iq_train['fitted'] = iq_best_model.fittedvalues
iq_train.fitted.plot(ax=axes[1], label="Predictions")
iq_train.total_cases.plot(ax=axes[1], label="Actual")

plt.suptitle("Dengue Predicted Cases vs. Actual Cases")
plt.legend()
# Out:
# best alpha =  1e-08
# best score =  6.883333333333334

# %%
test_features = pd.read_csv('data-processed/dengue_features_test.csv',
                             index_col=[0,1,2])

# %%
test_features_shifted1 = test_features.shift(1,axis = 0)
test_features_shifted2 = test_features.shift(2,axis = 0)

# %%
test_features_shifted1 = test_features_shifted1.rename(columns={'week_start_date':'week_start_date_pr1',
 'ndvi_ne':'ndvi_ne_pr1',
 'ndvi_nw':'ndvi_nw_pr1',
 'ndvi_se':'ndvi_se_Pr1',
 'ndvi_sw':'ndvi_sw_pr1',
 'precipitation_amt_mm':'precipitation_amt_mm_pr1',
 'reanalysis_air_temp_k':'reanalysis_air_temp_k_pr1',
 'reanalysis_avg_temp_k':'reanalysis_avg_temp_k_pr1',
 'reanalysis_dew_point_temp_k':'reanalysis_dew_point_temp_k_pr1',
 'reanalysis_max_air_temp_k':'reanalysis_max_air_temp_k_pr1',
 'reanalysis_min_air_temp_k':'reanalysis_min_air_temp_k_pr1',
 'reanalysis_precip_amt_kg_per_m2':'reanalysis_precip_amt_kg_per_m2_pr1',
 'reanalysis_relative_humidity_percent':'reanalysis_relative_humidity_percent_pr1',
 'reanalysis_sat_precip_amt_mm':'reanalysis_sat_precip_amt_mm_pr1',
 'reanalysis_specific_humidity_g_per_kg':'reanalysis_specific_humidity_g_per_kg_pr1',
 'reanalysis_tdtr_k':'reanalysis_tdtr_k_pr1',
 'station_avg_temp_c':'station_avg_temp_c_pr1',
 'station_diur_temp_rng_c':'station_diur_temp_rng_c_pr1',
 'station_max_temp_c':'station_max_temp_c_pr1',
 'station_min_temp_c':'station_min_temp_c_pr1',
 'station_precip_mm':'station_precip_mm_pr1'})

# %%
test_features_shifted2 = test_features_shifted2.rename(columns={'week_start_date':'week_start_date_pr2',
 'ndvi_ne':'ndvi_ne_pr2',
 'ndvi_nw':'ndvi_nw_pr2',
 'ndvi_se':'ndvi_se_Pr2',
 'ndvi_sw':'ndvi_sw_pr2',
 'precipitation_amt_mm':'precipitation_amt_mm_pr2',
 'reanalysis_air_temp_k':'reanalysis_air_temp_k_pr2',
 'reanalysis_avg_temp_k':'reanalysis_avg_temp_k_pr2',
 'reanalysis_dew_point_temp_k':'reanalysis_dew_point_temp_k_pr2',
 'reanalysis_max_air_temp_k':'reanalysis_max_air_temp_k_pr2',
 'reanalysis_min_air_temp_k':'reanalysis_min_air_temp_k_pr2',
 'reanalysis_precip_amt_kg_per_m2':'reanalysis_precip_amt_kg_per_m2_pr2',
 'reanalysis_relative_humidity_percent':'reanalysis_relative_humidity_percent_pr2',
 'reanalysis_sat_precip_amt_mm':'reanalysis_sat_precip_amt_mm_pr2',
 'reanalysis_specific_humidity_g_per_kg':'reanalysis_specific_humidity_g_per_kg_pr2',
 'reanalysis_tdtr_k':'reanalysis_tdtr_k_pr2',
 'station_avg_temp_c':'station_avg_temp_c_pr2',
 'station_diur_temp_rng_c':'station_diur_temp_rng_c_pr2',
 'station_max_temp_c':'station_max_temp_c_pr2',
 'station_min_temp_c':'station_min_temp_c_pr2',
 'station_precip_mm':'station_precip_mm_pr2'})

# %%
df_test = pd.merge(test_features_shifted1, test_features_shifted2, how='inner',on =['city','year','weekofyear' ])

# %%
shifted_testset_full = pd.merge(df_test, test_features, how='inner',on =['city','year','weekofyear' ])

# %%
shifted_testset_full.shape
# Out:
# (416, 66)

# %%
pd.isnull(shifted_testset_full).any()
# Out:
# week_start_date_pr1                           True
# ndvi_ne_pr1                                   True
# ndvi_nw_pr1                                   True
# ndvi_se_Pr1                                   True
# ndvi_sw_pr1                                   True
# precipitation_amt_mm_pr1                      True
# reanalysis_air_temp_k_pr1                     True
# reanalysis_avg_temp_k_pr1                     True
# reanalysis_dew_point_temp_k_pr1               True
# reanalysis_max_air_temp_k_pr1                 True
# reanalysis_min_air_temp_k_pr1                 True
# reanalysis_precip_amt_kg_per_m2_pr1           True
# reanalysis_relative_humidity_percent_pr1      True
# reanalysis_sat_precip_amt_mm_pr1              True
# reanalysis_specific_humidity_g_per_kg_pr1     True
# reanalysis_tdtr_k_pr1                         True
# station_avg_temp_c_pr1                        True
# station_diur_temp_rng_c_pr1                   True
# station_max_temp_c_pr1                        True
# station_min_temp_c_pr1                        True
# station_precip_mm_pr1                         True
# months_x                                      True
# week_start_date_pr2                           True
# ndvi_ne_pr2                                   True
# ndvi_nw_pr2                                   True
# ndvi_se_Pr2                                   True
# ndvi_sw_pr2                                   True
# precipitation_amt_mm_pr2                      True
# reanalysis_air_temp_k_pr2                     True
# reanalysis_avg_temp_k_pr2                     True
#                                              ...
# reanalysis_specific_humidity_g_per_kg_pr2     True
# reanalysis_tdtr_k_pr2                         True
# station_avg_temp_c_pr2                        True
# station_diur_temp_rng_c_pr2                   True
# station_max_temp_c_pr2                        True
# station_min_temp_c_pr2                        True
# station_precip_mm_pr2                         True
# months_y                                      True
# week_start_date                              False
# ndvi_ne                                      False
# ndvi_nw                                      False
# ndvi_se                                      False
# ndvi_sw                                      False
# precipitation_amt_mm                         False
# reanalysis_air_temp_k                        False
# reanalysis_avg_temp_k                        False
# reanalysis_dew_point_temp_k                  False
# reanalysis_max_air_temp_k                    False
# reanalysis_min_air_temp_k                    False
# reanalysis_precip_amt_kg_per_m2              False
# reanalysis_relative_humidity_percent         False
# reanalysis_sat_precip_amt_mm                 False
# reanalysis_specific_humidity_g_per_kg        False
# reanalysis_tdtr_k                            False
# station_avg_temp_c                           False
# station_diur_temp_rng_c                      False
# station_max_temp_c                           False
# station_min_temp_c                           False
# station_precip_mm                            False
# months                                       False
# Length: 66, dtype: bool

# %%
shifted_testset_full.drop('week_start_date', axis=1, inplace=True)
shifted_testset_full.drop('week_start_date_pr1', axis=1, inplace=True)
shifted_testset_full.drop('week_start_date_pr2', axis=1, inplace=True)

# %%
shifted_testset_full.fillna(shifted_testset_full.mean(), inplace=True)

# %%
shifted_testset_full
# Out:
#                       ndvi_ne_pr1  ndvi_nw_pr1  ndvi_se_Pr1  ndvi_sw_pr1  \
# city year weekofyear
# sj   2008 18             0.115997     0.124871     0.207123     0.201490
#           19            -0.018900    -0.018900     0.102729     0.091200
#           20            -0.018000    -0.012400     0.082043     0.072314
#           21            -0.001500     0.001241     0.151083     0.091529
#           22            -0.027575    -0.019867     0.124329     0.125686
#           23             0.056800     0.039833     0.062267     0.075914
#           24            -0.044000    -0.030467     0.132000     0.083529
#           25            -0.044300    -0.024925     0.132271     0.159157
#           26             0.035602     0.082150     0.144371     0.116729
#           27             0.010800     0.049900     0.100571     0.117329
#           28             0.072667     0.106660     0.155429     0.164900
#           29            -0.046450     0.006825     0.260286     0.214729
#           30             0.060079     0.051660     0.195843     0.176157
#           31             0.208300     0.429500     0.277683     0.245650
#           32             0.000200     0.003900     0.109067     0.086483
#           33             0.112200     0.032200     0.194186     0.205771
#           34            -0.063938    -0.019017     0.058900     0.065643
#           35             0.289150     0.241033     0.240600     0.208557
#           36             0.113200     0.085794     0.226083     0.198243
#           37             0.043304     0.017300     0.190417     0.119983
#           38             0.361900     0.649000     0.146400     0.131386
#           39             0.091375     0.164050     0.251667     0.196450
#           40             0.079500     0.103675     0.282686     0.261300
#           41            -0.137350     0.130950     0.271886     0.270029
#           42             0.130600     0.089700     0.186086     0.196443
#           43             0.183400     0.117550     0.152457     0.142500
#           44             0.033250     0.074867     0.336314     0.252657
#           45             0.083400     0.075700     0.073629     0.123729
#           46            -0.094400    -0.004950     0.143800     0.130314
#           47             0.101100     0.074000     0.237600     0.175529
# ...                           ...          ...          ...          ...
# iq   2012 48             0.319814     0.296857     0.272471     0.349329
#           49             0.376286     0.388143     0.433229     0.362914
#           50             0.367617     0.354980     0.325817     0.281133
#           51             0.130650     0.265457     0.223043     0.136517
#      2013 1              0.256983     0.223471     0.233883     0.253100
#           2              0.255829     0.268657     0.268414     0.244471
#           3              0.188229     0.139143     0.252729     0.170586
#           4              0.252200     0.184743     0.241700     0.233014
#           5              0.183729     0.127057     0.165986     0.163729
#           6              0.368857     0.375329     0.336871     0.418014
#           7              0.274957     0.270914     0.293043     0.294400
#           8              0.267029     0.190729     0.279186     0.282186
#           9              0.297967     0.327750     0.244357     0.308671
#           10             0.345517     0.346867     0.337117     0.382550
#           11             0.295343     0.309857     0.254686     0.263729
#           12             0.223671     0.119450     0.224800     0.228371
#           13             0.231800     0.195583     0.204786     0.250186
#           14             0.263429     0.210614     0.269414     0.245871
#           15             0.223543     0.208543     0.239971     0.218557
#           16             0.263200     0.237400     0.250143     0.199114
#           17             0.309029     0.270267     0.235500     0.259686
#           18             0.193314     0.247057     0.275643     0.372729
#           19             0.385143     0.369700     0.375933     0.354214
#           20             0.396343     0.292471     0.333400     0.352271
#           21             0.352557     0.281050     0.307071     0.277400
#           22             0.236829     0.293857     0.223443     0.299429
#           23             0.301471     0.380029     0.280629     0.383186
#           24             0.247600     0.296343     0.285371     0.350357
#           25             0.238729     0.251029     0.252586     0.249771
#           26             0.310429     0.302700     0.406614     0.403943
#
#                       precipitation_amt_mm_pr1  reanalysis_air_temp_k_pr1  \
# city year weekofyear
# sj   2008 18                         38.138157                 298.805748
#           19                         78.600000                 298.492857
#           20                         12.560000                 298.475714
#           21                          3.660000                 299.455714
#           22                          0.000000                 299.690000
#           23                          0.760000                 299.780000
#           24                         71.170000                 299.768571
#           25                         48.990000                 300.062857
#           26                         30.810000                 300.484286
#           27                          8.020000                 300.601429
#           28                         17.520000                 300.497143
#           29                         16.370000                 300.214286
#           30                          4.340000                 300.448571
#           31                          3.390000                 300.598571
#           32                         13.730000                 300.730000
#           33                         50.940000                 300.741429
#           34                          4.280000                 301.150000
#           35                         31.970000                 300.735714
#           36                         19.670000                 301.022857
#           37                         60.560000                 301.225714
#           38                        126.680000                 300.804286
#           39                         48.440000                 300.757143
#           40                        153.790000                 300.378571
#           41                         54.960000                 300.564286
#           42                          6.160000                 300.715714
#           43                         60.420000                 300.234286
#           44                         91.700000                 299.734286
#           45                          0.000000                 300.352857
#           46                         12.230000                 300.077143
#           47                         12.640000                 300.137143
# ...                                        ...                        ...
# iq   2012 48                         47.310000                 297.890000
#           49                         42.660000                 298.371429
#           50                         35.150000                 299.160000
#           51                        102.240000                 298.665714
#      2013 1                          50.420000                 298.612857
#           2                          35.330000                 298.007143
#           3                          33.140000                 296.241429
#           4                          44.020000                 296.971429
#           5                          97.260000                 297.698571
#           6                          43.530000                 297.625714
#           7                          97.800000                 298.005714
#           8                         129.230000                 297.817143
#           9                          66.470000                 297.747143
#           10                         39.190000                 297.000000
#           11                        111.090000                 296.958571
#           12                         27.210000                 297.935714
#           13                         76.860000                 298.188571
#           14                        104.470000                 298.327143
#           15                        122.600000                 297.621429
#           16                         88.070000                 297.754286
#           17                         44.300000                 298.647143
#           18                         71.070000                 297.202857
#           19                          2.280000                 297.981429
#           20                         62.520000                 298.310000
#           21                         46.270000                 297.367143
#           22                         87.290000                 296.880000
#           23                         41.120000                 297.774286
#           24                         71.520000                 297.167143
#           25                         78.960000                 295.831429
#           26                         39.540000                 295.778571
#
#                       reanalysis_avg_temp_k_pr1  \
# city year weekofyear
# sj   2008 18                         299.341820
#           19                         298.550000
#           20                         298.557143
#           21                         299.357143
#           22                         299.728571
#           23                         299.671429
#           24                         299.728571
#           25                         300.007143
#           26                         300.578571
#           27                         300.621429
#           28                         300.528571
#           29                         300.342857
#           30                         300.607143
#           31                         300.721429
#           32                         300.885714
#           33                         300.842857
#           34                         301.285714
#           35                         300.814286
#           36                         301.135714
#           37                         301.314286
#           38                         300.935714
#           39                         300.871429
#           40                         300.450000
#           41                         300.771429
#           42                         300.742857
#           43                         300.278571
#           44                         299.878571
#           45                         300.557143
#           46                         300.142857
#           47                         300.292857
# ...                                         ...
# iq   2012 48                         298.750000
#           49                         299.192857
#           50                         300.528571
#           51                         299.914286
#      2013 1                          299.771429
#           2                          298.771429
#           3                          297.400000
#           4                          298.021429
#           5                          298.964286
#           6                          298.571429
#           7                          299.678571
#           8                          298.992857
#           9                          298.942857
#           10                         298.707143
#           11                         298.064286
#           12                         299.621429
#           13                         299.407143
#           14                         299.885714
#           15                         299.157143
#           16                         299.485714
#           17                         299.778571
#           18                         297.928571
#           19                         299.200000
#           20                         299.792857
#           21                         298.157143
#           22                         297.792857
#           23                         298.964286
#           24                         298.328571
#           25                         296.607143
#           26                         297.400000
#
#                       reanalysis_dew_point_temp_k_pr1  \
# city year weekofyear
# sj   2008 18                               295.399356
#           19                               294.527143
#           20                               294.395714
#           21                               295.308571
#           22                               294.402857
#           23                               294.760000
#           24                               295.314286
#           25                               295.650000
#           26                               295.997143
#           27                               296.268571
#           28                               296.411429
#           29                               295.824286
#           30                               296.177143
#           31                               296.512857
#           32                               296.202857
#           33                               297.047143
#           34                               296.912857
#           35                               296.828571
#           36                               297.218571
#           37                               297.400000
#           38                               297.275714
#           39                               297.081429
#           40                               296.535714
#           41                               296.882857
#           42                               296.164286
#           43                               296.200000
#           44                               295.888571
#           45                               295.407143
#           46                               296.432857
#           47                               295.854286
# ...                                               ...
# iq   2012 48                               297.517143
#           49                               297.725714
#           50                               296.494286
#           51                               297.082857
#      2013 1                                297.228571
#           2                                296.598571
#           3                                295.275714
#           4                                295.312857
#           5                                296.708571
#           6                                296.045714
#           7                                296.985714
#           8                                296.377143
#           9                                296.782857
#           10                               296.245714
#           11                               296.470000
#           12                               297.038571
#           13                               297.562857
#           14                               297.141429
#           15                               296.518571
#           16                               296.300000
#           17                               296.885714
#           18                               296.561429
#           19                               293.228571
#           20                               296.792857
#           21                               296.435714
#           22                               295.850000
#           23                               295.638571
#           24                               295.845714
#           25                               294.894286
#           26                               293.648571
#
#                       reanalysis_max_air_temp_k_pr1  \
# city year weekofyear
# sj   2008 18                             303.601389
#           19                             301.100000
#           20                             300.800000
#           21                             302.200000
#           22                             303.000000
#           23                             302.300000
#           24                             301.900000
#           25                             302.400000
#           26                             303.500000
#           27                             302.500000
#           28                             302.300000
#           29                             301.700000
#           30                             302.300000
#           31                             302.300000
#           32                             302.700000
#           33                             302.500000
#           34                             303.300000
#           35                             302.600000
#           36                             303.200000
#           37                             303.500000
#           38                             303.600000
#           39                             303.300000
#           40                             303.300000
#           41                             303.400000
#           42                             303.000000
#           43                             303.400000
#           44                             302.600000
#           45                             302.200000
#           46                             302.600000
#           47                             303.300000
# ...                                             ...
# iq   2012 48                             302.800000
#           49                             306.400000
#           50                             307.100000
#           51                             306.500000
#      2013 1                              305.800000
#           2                              303.900000
#           3                              306.700000
#           4                              306.800000
#           5                              306.900000
#           6                              307.400000
#           7                              307.100000
#           8                              305.300000
#           9                              305.500000
#           10                             305.900000
#           11                             303.700000
#           12                             305.400000
#           13                             305.300000
#           14                             307.500000
#           15                             305.300000
#           16                             307.900000
#           17                             309.500000
#           18                             304.000000
#           19                             308.600000
#           20                             307.800000
#           21                             304.000000
#           22                             305.800000
#           23                             305.500000
#           24                             306.300000
#           25                             304.600000
#           26                             305.900000
#
#                       reanalysis_min_air_temp_k_pr1  ...  \
# city year weekofyear                                 ...
# sj   2008 18                              295.74774  ...
#           19                              296.40000  ...
#           20                              296.70000  ...
#           21                              296.40000  ...
#           22                              296.90000  ...
#           23                              297.30000  ...
#           24                              297.60000  ...
#           25                              297.50000  ...
#           26                              297.50000  ...
#           27                              298.50000  ...
#           28                              298.70000  ...
#           29                              299.00000  ...
#           30                              298.70000  ...
#           31                              298.90000  ...
#           32                              299.20000  ...
#           33                              299.10000  ...
#           34                              299.00000  ...
#           35                              298.60000  ...
#           36                              298.90000  ...
#           37                              298.90000  ...
#           38                              298.80000  ...
#           39                              298.90000  ...
#           40                              298.10000  ...
#           41                              297.40000  ...
#           42                              298.70000  ...
#           43                              298.00000  ...
#           44                              297.80000  ...
#           45                              298.40000  ...
#           46                              298.20000  ...
#           47                              297.90000  ...
# ...                                             ...  ...
# iq   2012 48                              294.30000  ...
#           49                              295.00000  ...
#           50                              294.70000  ...
#           51                              294.40000  ...
#      2013 1                               294.10000  ...
#           2                               294.10000  ...
#           3                               292.90000  ...
#           4                               292.80000  ...
#           5                               293.60000  ...
#           6                               292.70000  ...
#           7                               293.90000  ...
#           8                               293.50000  ...
#           9                               294.10000  ...
#           10                              292.70000  ...
#           11                              294.20000  ...
#           12                              294.40000  ...
#           13                              294.60000  ...
#           14                              294.10000  ...
#           15                              294.30000  ...
#           16                              293.70000  ...
#           17                              294.00000  ...
#           18                              293.00000  ...
#           19                              289.40000  ...
#           20                              293.30000  ...
#           21                              293.30000  ...
#           22                              292.50000  ...
#           23                              292.70000  ...
#           24                              291.60000  ...
#           25                              290.70000  ...
#           26                              292.50000  ...
#
#                       reanalysis_relative_humidity_percent  \
# city year weekofyear
# sj   2008 18                                     78.781429
#           19                                     78.230000
#           20                                     78.270000
#           21                                     73.015714
#           22                                     74.084286
#           23                                     76.557143
#           24                                     76.844286
#           25                                     76.870000
#           26                                     77.395714
#           27                                     78.534286
#           28                                     77.021429
#           29                                     77.615714
#           30                                     78.560000
#           31                                     76.521429
#           32                                     80.371429
#           33                                     77.968571
#           34                                     79.547143
#           35                                     79.864286
#           36                                     80.024286
#           37                                     81.324286
#           38                                     80.448571
#           39                                     79.861429
#           40                                     80.420000
#           41                                     76.361429
#           42                                     78.658571
#           43                                     79.492857
#           44                                     74.505714
#           45                                     80.618571
#           46                                     77.634286
#           47                                     78.640000
# ...                                                    ...
# iq   2012 48                                     96.572857
#           49                                     87.357143
#           50                                     92.022857
#           51                                     92.920000
#      2013 1                                      92.862857
#           2                                      95.232857
#           3                                      91.802857
#           4                                      94.872857
#           5                                      92.512857
#           6                                      94.752857
#           7                                      92.905714
#           8                                      95.311429
#           9                                      96.022857
#           10                                     97.478571
#           11                                     95.540000
#           12                                     96.748571
#           13                                     94.218571
#           14                                     94.630000
#           15                                     93.091429
#           16                                     91.862857
#           17                                     96.580000
#           18                                     77.757143
#           19                                     92.250000
#           20                                     95.338571
#           21                                     94.740000
#           22                                     89.990000
#           23                                     93.891429
#           24                                     94.967143
#           25                                     89.057143
#           26                                     87.030000
#
#                       reanalysis_sat_precip_amt_mm  \
# city year weekofyear
# sj   2008 18                                 78.60
#           19                                 12.56
#           20                                  3.66
#           21                                  0.00
#           22                                  0.76
#           23                                 71.17
#           24                                 48.99
#           25                                 30.81
#           26                                  8.02
#           27                                 17.52
#           28                                 16.37
#           29                                  4.34
#           30                                  3.39
#           31                                 13.73
#           32                                 50.94
#           33                                  4.28
#           34                                 31.97
#           35                                 19.67
#           36                                 60.56
#           37                                126.68
#           38                                 48.44
#           39                                153.79
#           40                                 54.96
#           41                                  6.16
#           42                                 60.42
#           43                                 91.70
#           44                                  0.00
#           45                                 12.23
#           46                                 12.64
#           47                                 22.49
# ...                                            ...
# iq   2012 48                                 42.66
#           49                                 35.15
#           50                                102.24
#           51                                 50.42
#      2013 1                                  35.33
#           2                                  33.14
#           3                                  44.02
#           4                                  97.26
#           5                                  43.53
#           6                                  97.80
#           7                                 129.23
#           8                                  66.47
#           9                                  39.19
#           10                                111.09
#           11                                 27.21
#           12                                 76.86
#           13                                104.47
#           14                                122.60
#           15                                 88.07
#           16                                 44.30
#           17                                 71.07
#           18                                  2.28
#           19                                 62.52
#           20                                 46.27
#           21                                 87.29
#           22                                 41.12
#           23                                 71.52
#           24                                 78.96
#           25                                 39.54
#           26                                 51.80
#
#                       reanalysis_specific_humidity_g_per_kg  \
# city year weekofyear
# sj   2008 18                                      15.918571
#           19                                      15.791429
#           20                                      16.674286
#           21                                      15.775714
#           22                                      16.137143
#           23                                      16.667143
#           24                                      17.010000
#           25                                      17.420000
#           26                                      17.678571
#           27                                      17.808571
#           28                                      17.201429
#           29                                      17.571429
#           30                                      17.940000
#           31                                      17.608571
#           32                                      18.547143
#           33                                      18.418571
#           34                                      18.355714
#           35                                      18.777143
#           36                                      19.091429
#           37                                      18.901429
#           38                                      18.595714
#           39                                      18.034286
#           40                                      18.428571
#           41                                      17.617143
#           42                                      17.658571
#           43                                      17.337143
#           44                                      16.811429
#           45                                      17.891429
#           46                                      17.305714
#           47                                      17.108571
# ...                                                     ...
# iq   2012 48                                      19.598571
#           49                                      18.201429
#           50                                      18.844286
#           51                                      19.028571
#      2013 1                                       18.262857
#           2                                       16.788571
#           3                                       16.902857
#           4                                       18.391429
#           5                                       17.618571
#           6                                       18.724286
#           7                                       18.040000
#           8                                       18.465714
#           9                                       17.891429
#           10                                      18.120000
#           11                                      18.754286
#           12                                      19.377143
#           13                                      18.892857
#           14                                      18.148571
#           15                                      17.910000
#           16                                      18.632857
#           17                                      18.180000
#           18                                      14.852857
#           19                                      18.478571
#           20                                      18.038571
#           21                                      17.382857
#           22                                      17.185714
#           23                                      17.448571
#           24                                      16.410000
#           25                                      15.137143
#           26                                      16.148571
#
#                       reanalysis_tdtr_k  station_avg_temp_c  \
# city year weekofyear
# sj   2008 18                   3.128571           26.528571
#           19                   2.571429           26.071429
#           20                   4.428571           27.928571
#           21                   4.342857           28.057143
#           22                   3.542857           27.614286
#           23                   2.857143           28.000000
#           24                   3.157143           27.400000
#           25                   3.900000           28.757143
#           26                   2.785714           28.657143
#           27                   2.228571           28.457143
#           28                   2.028571           27.714286
#           29                   2.614286           28.785714
#           30                   2.585714           28.685714
#           31                   2.800000           28.985714
#           32                   2.428571           28.357143
#           33                   2.742857           29.214286
#           34                   2.542857           28.971429
#           35                   2.700000           28.857143
#           36                   3.371429           29.357143
#           37                   2.985714           28.385714
#           38                   3.114286           28.228571
#           39                   2.814286           27.400000
#           40                   3.057143           28.357143
#           41                   2.914286           28.171429
#           42                   3.128571           27.214286
#           43                   2.528571           27.014286
#           44                   2.571429           27.642857
#           45                   2.600000           27.614286
#           46                   3.300000           27.385714
#           47                   2.514286           26.814286
# ...                                 ...                 ...
# iq   2012 48                   7.471429           28.050000
#           49                  10.171429           28.600000
#           50                   9.285714           27.880000
#           51                   8.600000           28.233333
#      2013 1                    6.628571           28.475000
#           2                    6.571429           26.450000
#           3                    7.528571           26.700000
#           4                    8.214286           27.966667
#           5                    7.600000           26.700000
#           6                    9.528571           28.350000
#           7                    7.785714           27.800000
#           8                    6.914286           27.120000
#           9                    7.700000           27.600000
#           10                   6.185714           27.733333
#           11                   8.328571           28.366667
#           12                   7.128571           27.900000
#           13                   8.942857           28.150000
#           14                   8.000000           28.700000
#           15                   9.400000           27.633333
#           16                   8.357143           28.333333
#           17                   7.200000           26.950000
#           18                  14.285714           27.250000
#           19                   9.671429           28.450000
#           20                   6.400000           28.233333
#           21                   6.700000           26.633333
#           22                  10.100000           27.400000
#           23                   9.657143           27.520000
#           24                   7.385714           27.200000
#           25                   8.228571           26.700000
#           26                  11.542857           27.350000
#
#                       station_diur_temp_rng_c  station_max_temp_c  \
# city year weekofyear
# sj   2008 18                         7.057143                33.3
#           19                         5.557143                30.0
#           20                         7.785714                32.8
#           21                         6.271429                33.3
#           22                         7.085714                33.3
#           23                         5.171429                32.8
#           24                         6.042857                31.1
#           25                         6.985714                34.4
#           26                         6.242857                32.8
#           27                         4.628571                31.1
#           28                         5.914286                31.1
#           29                         5.014286                31.7
#           30                         6.314286                32.8
#           31                         6.171429                32.8
#           32                         5.857143                32.2
#           33                         6.342857                33.9
#           34                         5.328571                32.2
#           35                         5.471429                32.2
#           36                         6.414286                35.0
#           37                         6.428571                34.4
#           38                         6.271429                32.8
#           39                         5.857143                32.2
#           40                         7.057143                34.4
#           41                         5.942857                31.7
#           42                         6.200000                32.8
#           43                         5.328571                31.7
#           44                         5.742857                31.1
#           45                         5.757143                31.1
#           46                         5.928571                30.6
#           47                         5.714286                30.6
# ...                                       ...                 ...
# iq   2012 48                        10.025000                33.8
#           49                        11.200000                35.4
#           50                        10.500000                34.6
#           51                        10.066667                34.3
#      2013 1                         10.450000                34.9
#           2                          7.900000                31.2
#           3                          7.466667                31.8
#           4                         10.033333                33.6
#           5                          6.450000                33.3
#           6                          9.050000                33.4
#           7                          8.600000                33.8
#           8                          9.240000                33.0
#           9                          9.566667                34.2
#           10                         9.533333                34.2
#           11                        10.533333                34.3
#           12                         9.166667                34.9
#           13                        11.150000                34.2
#           14                        10.833333                34.8
#           15                         9.533333                33.6
#           16                        10.000000                34.2
#           17                         9.350000                33.6
#           18                        13.125000                35.0
#           19                         9.850000                34.6
#           20                         9.400000                34.1
#           21                         8.900000                32.8
#           22                         9.050000                32.6
#           23                        10.720000                33.8
#           24                        10.075000                32.6
#           25                         8.480000                32.2
#           26                         9.675000                32.6
#
#                       station_min_temp_c  station_precip_mm  months
# city year weekofyear
# sj   2008 18                        21.7               75.2       4
#           19                        22.2               34.3       5
#           20                        22.8                3.0       5
#           21                        24.4                0.3       5
#           22                        23.3               84.1       5
#           23                        25.0               27.7       6
#           24                        23.3               91.7       6
#           25                        24.4                0.3       6
#           26                        23.9               28.7       6
#           27                        25.0                2.9       7
#           28                        23.9               22.1       7
#           29                        26.1                0.0       7
#           30                        24.4                7.1       7
#           31                        25.0                5.1       7
#           32                        23.9               37.6       8
#           33                        25.0                1.8       8
#           34                        24.4               54.9       8
#           35                        24.4               16.2       8
#           36                        25.0                6.9       9
#           37                        23.3               45.1       9
#           38                        24.4               20.4       9
#           39                        22.8              146.3       9
#           40                        22.2               37.1       9
#           41                        24.4                8.5      10
#           42                        22.8               73.0      10
#           43                        23.3               16.5      10
#           44                        23.9                6.4      10
#           45                        24.4               36.6      11
#           46                        23.9                6.4      11
#           47                        23.3               56.9      11
# ...                                  ...                ...     ...
# iq   2012 48                        22.2               50.0      12
#           49                        22.2               30.0      12
#           50                        21.0                3.0      12
#           51                        22.0               21.3      12
#      2013 1                         22.8               23.8       1
#           2                         21.2               86.8       1
#           3                         22.6               82.0       1
#           4                         22.5               36.8       1
#           5                         23.2               51.3       1
#           6                         22.4               15.0       2
#           7                         22.4               19.6       2
#           8                         21.7               33.3       2
#           9                         21.8              111.3       2
#           10                        22.6              149.9       3
#           11                        22.2               35.1       3
#           12                        22.8                0.0       3
#           13                        22.0               70.6       3
#           14                        21.8               36.8       4
#           15                        22.0               54.1       4
#           16                        22.4               53.6       4
#           17                        21.2               74.9       4
#           18                        18.2                8.9       4
#           19                        22.4                7.1       5
#           20                        21.4               38.6       5
#           21                        21.8               97.3       5
#           22                        21.8               33.0       5
#           23                        21.4               68.0       6
#           24                        21.6               93.2       6
#           25                        21.8               34.1       6
#           26                        22.0               14.9       6
#
# [416 rows x 63 columns]

# %%
sj_test = preprocess_data_sj(shifted_testset_full)
iq_test = preprocess_data_iq(shifted_testset_full)

# %%
#sj_test = (sj_test-sj_test.min())/(sj_test.max()-sj_test.min())
#iq_test = (iq_test-iq_test.min())/(iq_test.max()-iq_test.min())

# %%
sj_predictions = sj_best_model.predict(sj_test).astype(int)
iq_predictions = iq_best_model.predict(iq_test).astype(int)

submission = pd.read_csv("data-processed/submission_format.csv",
                         index_col=[0, 1, 2])

print(sj_predictions.shape)
print(iq_predictions.shape)
submission.total_cases = np.concatenate([sj_predictions, iq_predictions])
submission.to_csv("data-processed/benchmark.csv")
# Out:
# (260,)
# (156,)
